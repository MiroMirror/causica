# %% [markdown]
# # Causica Colab 快速入门
#
# 本 notebook 用于在 **Google Colab** 中快速安装并验证 Causica（从你的 GitHub fork 安装）。
#
# **使用前请将下方 `YOUR_GITHUB_USERNAME` 替换为你的 GitHub 用户名。**

# %% [markdown]
# ## 1. 安装 Causica

# %%
# 将 YOUR_GITHUB_USERNAME 替换为你的 GitHub 用户名
GITHUB_USER = "YOUR_GITHUB_USERNAME"

# !pip install -q git+https://github.com/{GITHUB_USER}/causica.git

print("安装完成！")

# %% [markdown]
# ## 2. 验证安装

# %%
import causica
import torch

print(f"Causica 版本: {causica.__version__}")
print(f"PyTorch 版本: {torch.__version__}")
print(f"Python 版本: {__import__('sys').version}")
print("\n✓ 安装验证成功！")

# %% [markdown]
# ## 3. 下一步
#
# 安装成功后，可运行完整示例。下方会生成你 fork 的 Colab 链接：

# %%
# 生成 Colab 示例链接（使用上方设置的 GITHUB_USER）
base = f"https://colab.research.google.com/github/{GITHUB_USER}/causica/blob/main/examples"
print("完整示例链接：")
print(f"  • 多投资归因: {base}/multi_investment_sales_attribution.ipynb")
print(f"  • CSuite 示例: {base}/csuite_example.ipynb")
